# %% [markdown]
# ## Dasturimizni boshlaymiz pandas kutubxonasini chaqiramiz va csv faylimizni uqiymiz va qanday ma'lumotlar borligini kuramiz!

# %% [markdown]
# ### 2024 yilda maʼlumotlarni ishlab chiquvchilarining ish haqi dataseti ustida ishlaymiz

# %% [markdown]
# **experience_level:** Kasbiy tajriba darajasi (masalan, yosh, o'rta, katta).
#
# **employment_type:** Ish shartnoma turi (masalan, to'liq ish vaqti, qismiy ish, shartnoma).
#
# **job_title:** Xodimning ma'lum bir lavozimi yoki unvoni (masalan, Ma'lumotlar Muhandisi).
#
# **salary:** Qabul qilingan mablag', asl valyutada.
#
# **salary_currency:** Qabul qilingan valyuta.
#
# **salary_in_usd:** Taqqoslash maqsadida AQSh dollari konvertatsiyasi.
#
# **employee_residence:** Xodimning yashash joyi.
#
# **remote_ratio:** Masofaviy ishning qancha foizini bajarish mumkin.
#
# **company_location:** Kompaniya joylashuvi, geografik joylashuvi.
#
# **company_size:** Odatda xodimlar soni asosida hisoblanadi.

# %%
import pandas as pd

df = pd.read_csv('Dataset salary 2024.csv')

df.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2024               SE              FT                AI Engineer
# 1       2024               SE              FT                AI Engineer
# 2       2024               SE              FT              Data Engineer
# 3       2024               SE              FT              Data Engineer
# 4       2024               SE              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  202730             USD         202730                 US             0
# 1   92118             USD          92118                 US             0
# 2  130500             USD         130500                 US             0
# 3   96000             USD          96000                 US             0
# 4  190000             USD         190000                 US             0
#
#   company_location company_size
# 0               US            M
# ...

# %% [markdown]
# #### Datasetimiz haqida m'lumot olamiz

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16534 entries, 0 to 16533
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           16534 non-null  int64
#  1   experience_level    16534 non-null  object
#  2   employment_type     16534 non-null  object
#  3   job_title           16534 non-null  object
#  4   salary              16534 non-null  int64
#  5   salary_currency     16534 non-null  object
#  6   salary_in_usd       16534 non-null  int64
#  7   employee_residence  16534 non-null  object
#  8   remote_ratio        16534 non-null  int64
#  9   company_location    16534 non-null  object
#  10  company_size        16534 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 1.4+ MB

# %% [markdown]
# #### Datasetimiz miqdori ma'lumot olamiz

# %%
df.shape
# Out:
# (16534, 11)

# %% [markdown]
# #### Databazamizni solishtiramiz va holatini kuramiz

# %%
df.describe()
# Out:
#           work_year        salary  salary_in_usd  remote_ratio
# count  16534.000000  1.653400e+04   16534.000000  16534.000000
# mean    2023.226866  1.637270e+05  149686.777973     32.003750
# std        0.713558  3.402057e+05   68505.293156     46.245158
# min     2020.000000  1.400000e+04   15000.000000      0.000000
# 25%     2023.000000  1.017630e+05  101125.000000      0.000000
# 50%     2023.000000  1.422000e+05  141300.000000      0.000000
# 75%     2024.000000  1.872000e+05  185900.000000    100.000000
# max     2024.000000  3.040000e+07  800000.000000    100.000000

# %% [markdown]
# #### Datasetimizdagi ma'lumotlarni kuramiz

# %%
df.values
# Out:
# array([[2024, 'SE', 'FT', ..., 0, 'US', 'M'],
#        [2024, 'SE', 'FT', ..., 0, 'US', 'M'],
#        [2024, 'SE', 'FT', ..., 0, 'US', 'M'],
#        ...,
#        [2020, 'EN', 'FT', ..., 100, 'US', 'S'],
#        [2020, 'EN', 'CT', ..., 100, 'US', 'L'],
#        [2021, 'SE', 'FT', ..., 50, 'IN', 'L']], dtype=object)

# %% [markdown]
# #### Datasetimizdagi colomlar yaniy ustunlarni kurish!

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# #### Datasetimizning indexini kuramiz

# %%
df.index
# Out:
# RangeIndex(start=0, stop=16534, step=1)

# %% [markdown]
# #### Datasetimizni oyliglar orqaliy sortlaymiz

# %%
df.sort_values('salary')
# Out:
#        work_year experience_level employment_type  \
# 16366       2020               EN              PT
# 10800       2022               MI              FT
# 15639       2021               EN              FT
# 5739        2024               EN              PT
# 13011       2020               EX              FT
# ...          ...              ...             ...
# 15768       2022               SE              FT
# 16271       2021               MI              FT
# 16364       2021               MI              FT
# 16434       2020               MI              FT
# 16455       2021               MI              FT
#
#                              job_title    salary salary_currency  \
# 16366                      ML Engineer     14000             EUR
# 10800  Business Intelligence Developer     15000             USD
# 15639       Machine Learning Developer     15000             USD
# 5739                      Data Science     15000             EUR
# ...

# %% [markdown]
# #### Kamayish tartibida sortlash!

# %%
df.sort_values('salary', ascending=False)
# Out:
#        work_year experience_level employment_type  \
# 16455       2021               MI              FT
# 16434       2020               MI              FT
# 16364       2021               MI              FT
# 16271       2021               MI              FT
# 15768       2022               SE              FT
# ...          ...              ...             ...
# 15936       2022               EN              FT
# 5739        2024               EN              PT
# 10800       2022               MI              FT
# 13011       2020               EX              FT
# 16366       2020               EN              PT
#
#                              job_title    salary salary_currency  \
# 16455                   Data Scientist  30400000             CLP
# 16434                   Data Scientist  11000000             HUF
# 16364                  BI Data Analyst  11000000             HUF
# 16271                      ML Engineer   8500000             JPY
# ...

# %% [markdown]
# #### Kub ustunlar blan sortlash!

# %%
df.sort_values(['salary', 'remote_ratio'])
# Out:
#        work_year experience_level employment_type  \
# 16366       2020               EN              PT
# 13011       2020               EX              FT
# 15936       2022               EN              FT
# 5739        2024               EN              PT
# 10800       2022               MI              FT
# ...          ...              ...             ...
# 15768       2022               SE              FT
# 16271       2021               MI              FT
# 16364       2021               MI              FT
# 16434       2020               MI              FT
# 16455       2021               MI              FT
#
#                              job_title    salary salary_currency  \
# 16366                      ML Engineer     14000             EUR
# 13011               Staff Data Analyst     15000             USD
# 15936                     Data Analyst     15000             USD
# 5739                      Data Science     15000             EUR
# ...

# %% [markdown]
# #### Kerakliy ustunni tanlash!

# %%
df['salary']
# Out:
# 0         202730
# 1          92118
# 2         130500
# 3          96000
# 4         190000
#           ...
# 16529     412000
# 16530     151000
# 16531     105000
# 16532     100000
# 16533    7000000
# Name: salary, Length: 16534, dtype: int64

# %% [markdown]
# #### Shart berish!

# %%
df['salary'] > 15000
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 16529    True
# 16530    True
# 16531    True
# 16532    True
# 16533    True
# Name: salary, Length: 16534, dtype: bool

# %%
df[df['salary'] > 16000]
# Out:
#        work_year experience_level employment_type                  job_title  \
# 0           2024               SE              FT                AI Engineer
# 1           2024               SE              FT                AI Engineer
# 2           2024               SE              FT              Data Engineer
# 3           2024               SE              FT              Data Engineer
# 4           2024               SE              FT  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 16529       2020               SE              FT             Data Scientist
# 16530       2021               MI              FT   Principal Data Scientist
# 16531       2020               EN              FT             Data Scientist
# 16532       2020               EN              CT      Business Data Analyst
# 16533       2021               SE              FT       Data Science Manager
#
# ...

# %%
df[df['work_year'] == 2024]
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2024               SE              FT                AI Engineer
# 1          2024               SE              FT                AI Engineer
# 2          2024               SE              FT              Data Engineer
# 3          2024               SE              FT              Data Engineer
# 4          2024               SE              FT  Machine Learning Engineer
# ...         ...              ...             ...                        ...
# 6073       2024               SE              FT               Data Analyst
# 6074       2024               SE              FT             Data Scientist
# 6075       2024               SE              FT             Data Scientist
# 6076       2024               SE              FT              Data Engineer
# 6077       2024               SE              FT              Data Engineer
#
# ...

# %%
df[(df['work_year'] == 2024) & (df['salary'] > 17000)]
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2024               SE              FT                AI Engineer
# 1          2024               SE              FT                AI Engineer
# 2          2024               SE              FT              Data Engineer
# 3          2024               SE              FT              Data Engineer
# 4          2024               SE              FT  Machine Learning Engineer
# ...         ...              ...             ...                        ...
# 6073       2024               SE              FT               Data Analyst
# 6074       2024               SE              FT             Data Scientist
# 6075       2024               SE              FT             Data Scientist
# 6076       2024               SE              FT              Data Engineer
# 6077       2024               SE              FT              Data Engineer
#
# ...

# %%
df['work_year'].isin([2024, 2023])
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 16529    False
# 16530    False
# 16531    False
# 16532    False
# 16533    False
# Name: work_year, Length: 16534, dtype: bool

# %% [markdown]
# #### Hisob kitob amalini yaratamiz

# %%
df['salary'] * 10
# Out:
# 0         2027300
# 1          921180
# 2         1305000
# 3          960000
# 4         1900000
#            ...
# 16529     4120000
# 16530     1510000
# 16531     1050000
# 16532     1000000
# 16533    70000000
# Name: salary, Length: 16534, dtype: int64

# %% [markdown]
# #### Yunalishlar buyicha urtacha ish haqi

# %%
df.groupby('job_title')['salary'].mean().reset_index()
# Out:
#                            job_title         salary
# 0                       AI Architect  252001.724138
# 1                       AI Developer  134684.210526
# 2                        AI Engineer  163626.866667
# 3                 AI Product Manager  141766.666667
# 4                      AI Programmer  764400.857143
# ..                               ...            ...
# 150               Sales Data Analyst   60000.000000
# 151           Software Data Engineer  120000.000000
# 152               Staff Data Analyst   84999.333333
# 153             Staff Data Scientist  134500.000000
# 154  Staff Machine Learning Engineer  185000.000000
#
# [155 rows x 2 columns]

# %% [markdown]
# #### yil buyicha

# %%
df.groupby('work_year')['salary'].mean().reset_index()
# Out:
#    work_year         salary
# 0       2020  356637.453333
# 1       2021  559350.990826
# 2       2022  167705.961934
# 3       2023  159319.800916
# 4       2024  152229.524477

# %% [markdown]
# #### Daraja buyicha

# %%
df.groupby('experience_level')['salary'].mean().sort_values()
# Out:
# experience_level
# EN    125831.628679
# MI    157116.976721
# SE    168852.493440
# EX    208064.343313
# Name: salary, dtype: float64

# %% [markdown]
# ##### Columni yangilash

# %%
df['oylik'] = df['salary'] / 12

# %%
df.rename(columns={'salary': 'ish_haqqi'})
# Out:
#        work_year experience_level employment_type                  job_title  \
# 0           2024               SE              FT                AI Engineer
# 1           2024               SE              FT                AI Engineer
# 2           2024               SE              FT              Data Engineer
# 3           2024               SE              FT              Data Engineer
# 4           2024               SE              FT  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 16529       2020               SE              FT             Data Scientist
# 16530       2021               MI              FT   Principal Data Scientist
# 16531       2020               EN              FT             Data Scientist
# 16532       2020               EN              CT      Business Data Analyst
# 16533       2021               SE              FT       Data Science Manager
#
# ...

# %% [markdown]
# #### Bush xonalarni aniqlash!

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# #### yangi data yaratish!

# %%
df.to_csv('yangi_data.csv', index=False)

# %% [markdown]
# #### UI yaratish

# %%
import matplotlib.pyplot as plt
import seaborn as sns

average_salary = df.groupby('experience_level')['salary_in_usd'].mean().reset_index()
plt.figure(figsize=(30, 15))

sns.barplot(y='salary_in_usd', x='experience_level', data=average_salary)

plt.xticks(fontsize=32, rotation=90)
plt.yticks(fontsize=32) 

plt.title('Darajalar buyicha ish haqqi!', fontsize=45)
plt.xlabel("O'rtacha ish haqi (USD)", fontsize=42)
plt.ylabel('Ish haqqi', fontsize=42)
plt.show()
