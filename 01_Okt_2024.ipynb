# %% [markdown]
# <a href="https://colab.research.google.com/github/UznetDev/Data-science-home-work/blob/main/01_Okt_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px

# %%
df = pd.read_csv('train.csv')

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
age = df['Age']
fare = df['Fare']

# %%
df[['Age', 'Fare']].corr()
# Out:
#            Age      Fare
# Age   1.000000  0.096067
# Fare  0.096067  1.000000

# %%
correlation = df['Age'].corr(df['Fare'])
print(correlation)
# Out:
# 0.0960666917690389
