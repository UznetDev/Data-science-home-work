# %% [markdown]
# <a href="https://colab.research.google.com/github/UznetDev/Data-science-home-work/blob/main/19_Noy_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf, acf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df = pd.read_csv('https://assets.datacamp.com/production/repositories/1120/datasets/850e5614f8de4b134f40b4eeca27c7d0b91aeed2/NOAA_TAVG.csv')
df.head()
# Out:
#    DATE  TAVG
# 0  1870  53.8
# 1  1871  51.3
# 2  1872  51.3
# 3  1873  50.9
# 4  1874  51.3

# %%
x = df['TAVG']
plot_acf(x, lags=20, alpha=0.05)

# %%
df.TAVG.plot()
# Out:
# <Axes: >

# %%
acf(x)
# Out:
# array([1.        , 0.56298432, 0.5162726 , 0.47942339, 0.48322109,
#        0.4078876 , 0.39453882, 0.4192282 , 0.4757498 , 0.36975981,
#        0.43172098, 0.41711641, 0.36133775, 0.32437625, 0.34552536,
#        0.28948587, 0.31440183, 0.28969306, 0.26901248, 0.22870709,
#        0.26779672, 0.24002452])

# %%
noise = np.random.normal(loc=0, scale=1, size=500)

# %%
print(plot_acf(noise))
# Out:
# Figure(640x480)

# %%
plt.plot(noise)

# %%
adfuller(x)
# Out:
# (-1.397876140626536,
#  0.5832938987871145,
#  7,
#  139,
#  {'1%': -3.4782936965183815,
#   '5%': -2.882567574015525,
#   '10%': -2.5779830117488745},
#  436.67112736672203)

# %%
adfuller(noise)
# Out:
# (-17.033921261971756,
#  8.287472728894496e-30,
#  1,
#  498,
#  {'1%': -3.4435494520411605,
#   '5%': -2.8673612117611267,
#   '10%': -2.5698704830567247},
#  1411.8654447653107)
